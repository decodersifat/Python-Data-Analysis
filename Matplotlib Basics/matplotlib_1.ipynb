# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, marker = 'o')
plt.show()

# %%
x_data = np.random.random(50) * 100
y_data = np.random.random(50) * 100

# %%
plt.scatter(x_data,y_data, c='blue', alpha= 0.5,marker = '*', s = 10)
plt.show()

# %%
years = [2006 + x for x in range(16)]
weights = [80,83,43,66,88,80,82,81,87,75,88,89,85,87,84,83]

plt.plot(years,weights, marker = '*',  linestyle = "--")

# %%
plt.plot(years,weights, marker = '*' ,lw = 12)

# %%
plt.bar(years,weights)
# Out:
# <BarContainer object of 16 artists>

# %%
x = ['python','java','c++','ruby','c#']
y = [80,60,30,23,54]

plt.bar(x , y , color= 'green', align='edge', width=.2,edgecolor = 'blue', lw= 5)
# Out:
# <BarContainer object of 5 artists>

# %%
ages = np.random.normal(20, 1.5, 1000)
ages
# Out:
# array([17.62238134, 23.56390144, 17.06599619, 20.34864915, 17.91979076,
#        20.33780074, 19.54077165, 17.15518836, 19.91964983, 16.40396164,
#        19.9179556 , 19.84974328, 17.93681809, 22.07813649, 20.84419278,
#        20.02527558, 22.09467841, 19.31808588, 21.02130204, 18.47675336,
#        22.32220896, 20.87828219, 21.07697249, 17.7923694 , 21.23947207,
#        17.29092729, 17.40879023, 20.83523255, 20.50849776, 19.5701479 ,
#        18.887365  , 18.72847748, 17.91012864, 17.54283957, 19.77143532,
#        20.65027917, 20.25085813, 20.34503929, 19.34458913, 19.25075965,
#        20.24731446, 20.73729141, 18.49446186, 21.34140563, 18.69959561,
#        17.51821713, 20.21706688, 20.54684421, 18.20277751, 17.49426477,
#        18.95855436, 21.10959561, 22.11015737, 19.12318413, 22.38916465,
#        23.22584813, 20.12580019, 19.10576661, 21.07028134, 22.12668736,
#        18.64668632, 20.87011765, 19.43807989, 18.42800848, 18.13373767,
# ...

# %%
plt.hist(ages)
# Out:
# (array([  7.,  30., 104., 235., 291., 217.,  88.,  27.,   0.,   1.]),
#  array([14.93472843, 16.06725839, 17.19978836, 18.33231832, 19.46484829,
#         20.59737825, 21.72990822, 22.86243818, 23.99496815, 25.12749811,
#         26.26002808]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)
